# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# 1. Copy the zip from Google Drive
# !cp "/content/drive/MyDrive/deepfake-detection.zip" /content/

# 2. Unzip it quietly
# !unzip -q /content/deepfake-detection.zip -d /content/

# 3. List the contents to see the exact case-sensitive folder name
# !ls /content/
# Out:
# cp: error reading '/content/drive/MyDrive/deepfake-detection.zip': Transport endpoint is not connected
# cp: failed to close '/content/drive/MyDrive/deepfake-detection.zip': Transport endpoint is not connected
# [/content/deepfake-detection.zip]
#   End-of-central-directory signature not found.  Either this file is not
#   a zipfile, or it constitutes one disk of a multi-part archive.  In the
#   latter case the central directory and zipfile comment will be found on
#   the last disk(s) of this archive.
# unzip:  cannot find zipfile directory in one of /content/deepfake-detection.zip or
#         /content/deepfake-detection.zip.zip, and cannot find /content/deepfake-detection.zip.ZIP, period.
# deepfake-detection.zip	sample_data

# %%
# 1. Delete the broken, half-copied zip file
# !rm -f /content/deepfake-detection.zip

# 2. Force remount the Google Drive to fix the "transport endpoint" error
from google.colab import drive
drive.flush_and_unmount()
drive.mount('/content/drive', force_remount=True)

# 3. Try copying again (this might take a minute or two for ~4GB)
# !cp "/content/drive/MyDrive/deepfake-detection.zip" /content/

# 4. Check the file size to make sure it fully copied (Should be around ~3.8GB)
# !ls -lh /content/deepfake-detection.zip

# 5. Unzip it quietly
# !unzip -q /content/deepfake-detection.zip -d /content/

# 6. Verify the folder exists
# !ls /content/deepfake-detection
# Out:
# Mounted at /content/drive
# -rw------- 1 root root 3.8G Apr  6 15:38 /content/deepfake-detection.zip
# dataset		    evaluate.py  predict.py   requirements.txt	   train.py
# deepfake_cnn.keras  model.py	 __pycache__  training_curves.png  utils.py

# %%
import os

# 1. Mount Drive just in case it disconnected
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# 2. Check if the zip needs to be copied
if not os.path.exists('/content/deepfake-detection.zip'):
    print("Copying zip file from Drive...")
    # !cp "/content/drive/MyDrive/deepfake-detection.zip" /content/

# 3. Check if the folder needs to be unzipped
if not os.path.exists('/content/deepfake-detection'):
    print("Unzipping files...")
    # !unzip -o -q /content/deepfake-detection.zip -d /content/

# 4. Navigate to the folder
print("Navigating to project folder...")
os.chdir('/content/deepfake-detection')

# 5. Install requirements and train
print("Installing requirements...")
# !pip install -q -r requirements.txt

print("Starting training...")
# !python train.py
# Out:
# Mounted at /content/drive
# Copying zip file from Drive...
# Unzipping files...
# Navigating to project folder...
# Installing requirements...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 620.7/620.7 MB 1.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 143.3 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tf-keras 2.19.0 requires tensorflow<2.20,>=2.19, but you have tensorflow 2.20.0 which is incompatible.
# tensorflow-decision-forests 1.12.0 requires tensorflow==2.19.0, but you have tensorflow 2.20.0 which is incompatible.
# tensorflow-text 2.19.0 requires tensorflow<2.20,>=2.19.0, but you have tensorflow 2.20.0 which is incompatible.
# Starting training...
# ...
